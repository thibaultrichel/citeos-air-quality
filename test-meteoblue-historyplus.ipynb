# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import time
import json
import requests
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
from urllib.parse import unquote_plus, quote_plus
pd.set_option('display.max_columns', None)

# %%
def parse_date(string):
    res = string.replace("T", " ").split(" ")
    date = "-".join([res[0][:4], res[0][4:6], res[0][6:]])
    hour = ":".join([res[1][:2], res[1][2:]])
    return " ".join([date, hour])

# %%
df = pd.read_csv("./data/data-test-bale-meteoblue-historyplus.csv", skiprows=10, names=["timestamp", "temperature", "humidity", "wind-speed", "wind-direction"])
df.timestamp = df.timestamp.apply(parse_date)
df["day"] = df.timestamp.apply(lambda x: x.split(" ")[0])
df = df[["timestamp", "day", "temperature", "humidity", "wind-speed", "wind-direction"]]
df
# Out:
#               timestamp         day  temperature  humidity  wind-speed  \
# 0      2019-01-01 00:00  2019-01-01     5.050529      90.0    4.680000
# 1      2019-01-01 01:00  2019-01-01     4.900528      91.0    4.693826
# 2      2019-01-01 02:00  2019-01-01     4.810529      91.0    4.829907
# 3      2019-01-01 03:00  2019-01-01     4.730528      92.0    5.351785
# 4      2019-01-01 04:00  2019-01-01     4.600529      92.0    5.241679
# ...                 ...         ...          ...       ...         ...
# 25579  2021-12-01 19:00  2021-12-01     7.940528      77.0   27.534704
# 25580  2021-12-01 20:00  2021-12-01     7.420528      79.0   24.149532
# 25581  2021-12-01 21:00  2021-12-01     6.930529      82.0   20.957443
# 25582  2021-12-01 22:00  2021-12-01     6.520528      84.0   18.844202
# 25583  2021-12-01 23:00  2021-12-01     6.720529      83.0   17.227419
#
#        wind-direction
# 0           292.61987
# 1           302.47120
# 2           296.56506
# ...

# %%
(df.day.value_counts() == 24).all()
# Out:
# True
